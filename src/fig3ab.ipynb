# %% [markdown]
# # Figura 3a y 3b
#
# El goal es hacer mapas de los sistemas 30x30

# %%
import os
import sys

import numpy as np
import pandas as pd

from tqdm import tqdm
from IPython.display import clear_output

import matplotlib as mpl 
import matplotlib.pyplot as plt

sys.path.insert(0, '../../icenumerics/')
sys.path.insert(0, './auxnumerics/')
import icenumerics as ice

import auxiliary as aux
import montecarlo_tools as mc
import chirality_tools as chir
from parameters import params
ureg = ice.ureg

# %reload_ext autoreload
# %autoreload 2

idx = pd.IndexSlice

# %%
plt.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
})

# %%
vis_path = '../data/sims'
params,ctrj,v,last_frame = aux.load_ctrj_and_vertices(params,vis_path,30,realization=1)

# %%
fig, axes = plt.subplots(1,2,figsize=(18,20))

ax = axes[0]
region_limit = params['size']*params['lattice_constant'].magnitude
N = params['size']
ice.draw_frame((aux.dropvis(ctrj)), frame_no=last_frame,
               region=[0,region_limit,0,region_limit],
               radius=params["particle_radius"].magnitude,
               cutoff=params["trap_sep"].magnitude/2,
               particle_color='#75b7ea',
               trap_color='gray',
               ax = ax)
v.display(ax,dpl_scale=0.5,dpl_width=2.5,circle_scale=0.5)


ax = axes[1]
region_limit = params['size']*params['lattice_constant'].magnitude
ice.draw_frame((aux.dropvis(ctrj)), frame_no=last_frame,
               region=[0,region_limit,0,region_limit],
               radius=params["particle_radius"].magnitude,
               cutoff=params["trap_sep"].magnitude/2,
               particle_color='#75b7ea',
               trap_color='gray',
               ax = ax)
v.display_afgroup(ax,dpl_scale=1,dpl_width=3,circle_scale=0.5)

# %%
fig.savefig('../data/figs/fig3ab.png',dpi=300,bbox_inches='tight')
fig.savefig('../data/figs/fig3ab.pdf',bbox_inches='tight')
