# %%
import os
import sys

import numpy as np
import math
import pandas as pd

from tqdm import tqdm
from IPython.display import clear_output

import matplotlib as mpl 
import matplotlib.pyplot as plt

sys.path.insert(0, '../../icenumerics/')
sys.path.insert(0, './auxnumerics/')
import icenumerics as ice


from parameters import params
import auxiliary as aux
import montecarlo as mc
import chirality_tools as chir
import energy as eg
from numba import jit
from numba_progress import ProgressBar

ureg = ice.ureg

# %reload_ext autoreload
# %autoreload 2

idx = pd.IndexSlice

# %%
plt.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
})

# %% [markdown]
# # Initialization

# %%
mu0 = (4*np.pi)*1e-7 * ureg.H/ureg.m
kb = 1.380649e-23 * ureg.J / ureg.K
kbT = (params['kb'] * params['sim_temp']).to(ureg.nm * ureg.pN).magnitude

# %%
N = 10
a = params['lattice_constant']

sp = ice.spins()
sp.create_lattice('square', [N,N], lattice_constant=a ,border='periodic')

particle = ice.particle(radius=params['particle_radius'],
                        susceptibility=params['particle_susceptibility'],
                        diffusion=params['particle_diffusion'],
                        temperature=params['particle_temperature'],
                        density=params['particle_density']
)

trap = ice.trap(trap_sep=params['trap_sep'],
                height=params['trap_height'],
                stiffness=params['trap_stiffness']
)


col = ice.colloidal_ice(sp, particle, trap,
                       height_spread=0,
                       susceptibility_spread=0.1,
                       periodic=True)

particle_radius = params['particle_radius']
col.region = np.array([[0,0,-3*(particle_radius/a/N).magnitude],[1,1,3*(particle_radius/a/N).magnitude]])*N*a

col.display()

# %%
def is_accepted(dE,kbT):
    arg = dE/kbT
    if dE<0:
        return True
    else:
        r = np.random.rand()
        if r<np.exp(arg):
            return True
        else:
            return False

def metropolis(centers, dirs, rels, prefactor, mcsteps=1000):
    
    atoms = centers + rels 
    a = np.round(params['lattice_constant'].magnitude, 5) 
    Eold = eg.calculate_energy(prefactor, N*a, atoms)
    
    print(Eold)
    for i in tqdm(range(mcsteps)):
        dirsnew, relsnew, pos = mc.flip_loop(a,N,centers,dirs,rels)
        
        newatoms = centers + relsnew
        Enew = eg.calculate_energy(prefactor, N*a, newatoms)
        
        dE = Enew - Eold
        
        if is_accepted(dE,kbT):
            
            dirs = dirsnew.copy()
            rels = relsnew.copy()
            Eold = Enew
        else:
            Eold=Eold
    
    print(Eold)

# %%
centers, dirs, rels = mc.trj2numpy(col.to_ctrj())

B = 1*ureg.mT
m = np.pi * (2*params['particle_radius'])**3 *params['particle_susceptibility']*B/6/mu0
prefactor =  - (mu0*m**2/4/np.pi).to(ureg.pN * ureg.nm * ureg.um**3).magnitude

metropolis(centers, dirs, rels, prefactor, mcsteps=1000)
# Out:
# -3268.557715442385
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:03<00:00, 331.09it/s]
# -3451.9643044539644

# %%
np.random.randint()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 np.random.randint()
#
# File numpy/random/mtrand.pyx:679, in numpy.random.mtrand.RandomState.randint()
#
# TypeError: randint() takes at least 1 positional argument (0 given)

# %% [markdown]
# # Import

# %%
fields = list(range(1,10+1))
datapath = '/media/frieren/BIG/stuckgs/data/metropolis/1M'
rpaths = {r:os.path.join(datapath,f'r{r}') for r in range(1,11)}
rpaths
# Out:
# {1: '/media/frieren/BIG/stuckgs/data/metropolis/1M/r1',
#  2: '/media/frieren/BIG/stuckgs/data/metropolis/1M/r2',
#  3: '/media/frieren/BIG/stuckgs/data/metropolis/1M/r3',
#  4: '/media/frieren/BIG/stuckgs/data/metropolis/1M/r4',
#  5: '/media/frieren/BIG/stuckgs/data/metropolis/1M/r5',
#  6: '/media/frieren/BIG/stuckgs/data/metropolis/1M/r6',
#  7: '/media/frieren/BIG/stuckgs/data/metropolis/1M/r7',
#  8: '/media/frieren/BIG/stuckgs/data/metropolis/1M/r8',
#  9: '/media/frieren/BIG/stuckgs/data/metropolis/1M/r9',
#  10: '/media/frieren/BIG/stuckgs/data/metropolis/1M/r10'}

# %%
import re
def get_field_values(path:str)-> dict:
    all_files = os.listdir(path)
    trj_files = [x for x in all_files if x.startswith('trj')]
    vrt_files = [x for x in all_files if x.startswith('vertices')]
    field_values = [re.search(r'(\d+\.\d+)', x).group(1) for x in vrt_files]
    return field_values

rfield_values = {r:get_field_values(path) for r,path in rpaths.items()}

# %%
def create_counts(path:str,field_vals:str)->None:
    for i,field in tqdm(enumerate(field_vals)):
        # importing the files
        TRJ_FILE = os.path.join(path,f'trj{field}.csv')
        VRT_FILE= os.path.join(path,f'vertices{field}.csv')
        trj = pd.read_csv(TRJ_FILE,index_col=['frame','id'])
        vertices = pd.read_csv(VRT_FILE,index_col=['frame','vertex'])

        # creating vertices object
        v = ice.vertices()
        v.vertices = vertices 
        v.vertices

        # getting the counts from the last frame
        last_frame = trj.index.get_level_values('frame').max()
        counts = ice.count_vertices(aux.classify_vertices(v.vertices))
        counts['field'] = [field]*len(counts)
        lf_counts = counts.loc[last_frame,:]

        # saving counts file
        if i==0:
            lf_counts.to_csv(os.path.join(path,'counts.csv'))
        else:
            lf_counts.to_csv(os.path.join(path,'counts.csv'),header=False,mode='a')

# %%
for r in range(1,11):
    print(f'{rpaths[r]=}')
    create_counts(rpaths[r],rfield_values[r])
# Out:
# rpaths[r]='/media/frieren/BIG/stuckgs/data/metropolis/1M/r1'
# 24it [02:16,  5.69s/it]
# rpaths[r]='/media/frieren/BIG/stuckgs/data/metropolis/1M/r2'
# 24it [02:19,  5.82s/it]
# rpaths[r]='/media/frieren/BIG/stuckgs/data/metropolis/1M/r3'
# 24it [04:12, 10.50s/it]
# rpaths[r]='/media/frieren/BIG/stuckgs/data/metropolis/1M/r4'
# 24it [08:11, 20.46s/it]
# rpaths[r]='/media/frieren/BIG/stuckgs/data/metropolis/1M/r5'
# 24it [06:54, 17.29s/it]
# rpaths[r]='/media/frieren/BIG/stuckgs/data/metropolis/1M/r6'
# 24it [08:41, 21.74s/it]
# rpaths[r]='/media/frieren/BIG/stuckgs/data/metropolis/1M/r7'
# 24it [04:49, 12.06s/it]
# rpaths[r]='/media/frieren/BIG/stuckgs/data/metropolis/1M/r8'
# 24it [05:42, 14.26s/it]
# rpaths[r]='/media/frieren/BIG/stuckgs/data/metropolis/1M/r9'
# 24it [05:47, 14.49s/it]
# rpaths[r]='/media/frieren/BIG/stuckgs/data/metropolis/1M/r10'
# 24it [03:48,  9.52s/it]

# %%
def load_counts(r):
    counts = pd.read_csv(os.path.join(datapath,f'r{r}','counts.csv'),index_col=['field','type'])
    return counts.sort_index()
all_counts = pd.concat([load_counts(i).fraction for i in range(1,11)],axis=1)
mean_counts = pd.DataFrame(all_counts.mean(axis=1),columns=['fraction'])
counts_vector = np.array([stuff.fraction.to_list() for B,stuff in mean_counts.groupby('field')])
fields = counts.index.get_level_values('field').unique().to_list()

# %%
mapping = {
    1:'I',
    2:'II',
    3:'III',
    4:'VI',
    5:'V',
    6:'IV',
}
mean_counts.index = mean_counts.index.set_levels(
    mean_counts.index.levels[1].map(mapping),
    level=1
)
# Out:
#             fraction
# field type
# 0.0   I        0.068
#       II       0.249
#       III      0.120
#       VI       0.237
#       V        0.267
# ...              ...
# 10.0  II       0.075
#       III      0.007
#       VI       0.022
#       V        0.073
#       IV       0.412
#
# [144 rows x 1 columns]

# %%
mean_counts.to_csv(os.path.join(datapath,'average_counts.csv'))

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(fields,counts_vector[:,0]+counts_vector[:,-1],label='I+VI')
ax.plot(fields,counts_vector[:,1]+counts_vector[:,-2],label='II+V')
ax.plot(fields,counts_vector[:,2],label='III')
ax.plot(fields,counts_vector[:,3],label='IV')

ax.set_xlabel('$B$ [mT]',fontsize=15)
ax.set_ylabel('$\\nu$',fontsize=15)
ax.set_ylim(0,1)
ax.set_xlim(0,10)

ax.grid()
ax.legend()
plt.show()
